# %%
import pandas
dfs = pandas.read_html('https://rate.bot.com.tw/cr?Lang=zh-TW')

# %%
type(dfs)
# Out:
# list

# %%
dfs[0]
# Out:
#              幣別                    活期(年息%)                    定期存款 (年息%)  \
#              幣別 Unnamed: 1_level_1 活期(年息%) Unnamed: 3_level_1        7 天
# 0      美金 (USD)               0.05   0.150              0.150      0.150
# 1   美金 (USD) 大額                  -   0.150              0.150      0.150
# 2      港幣 (HKD)               0.05   0.100              0.100      0.100
# 3      英鎊 (GBP)               0.05   0.080              0.080      0.080
# 4      澳幣 (AUD)               0.05   0.150              0.150      0.150
# 5    加拿大幣 (CAD)                0.1   0.150              0.150      0.150
# 6    新加坡幣 (SGD)               0.05   0.100              0.100      0.100
# 7    瑞士法郎 (CHF)              0.001   0.001              0.001      0.001
# 8      日圓 (JPY)              0.001   0.001              0.001      0.001
# 9     南非幣 (ZAR)                0.8   1.800              1.800      1.800
# 10    瑞典幣 (SEK)              0.001   0.001              0.001      0.001
# ...

# %%
money = dfs[0]
type(money)
# Out:
# pandas.core.frame.DataFrame

# %%
money.ix [:,0:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-10451b07b3d4> in <module>
# ----> 1 money.ix [:,0:2]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
dfs[0]
# Out:
#            幣別  結帳匯率 (NTD)        幣別.1  結帳匯率 (NTD).1
# 0    美金 (USD)     29.9900    港幣 (HKD)        3.8680
# 1    英鎊 (GBP)     36.9800    澳幣 (AUD)       19.9050
# 2  加拿大幣 (CAD)     21.7800  新加坡幣 (SGD)       21.1900
# 3  瑞士法郎 (CHF)     31.1250    日圓 (JPY)        0.2792
# 4   南非幣 (ZAR)      1.7140   瑞典幣 (SEK)        3.1600
# 5    紐元 (NZD)     18.6000    泰幣 (THB)        0.9470
# 6  菲國比索 (PHP)      0.5928   印尼幣 (IDR)        0.0020
# 7    歐元 (EUR)     33.2500    韓元 (KRW)        0.0242
# 8   越南盾 (VND)      0.0013   馬來幣 (MYR)        6.8950
# 9   人民幣 (CNY)      4.1850         NaN           NaN

# %%
money.ix[:,0:2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-cfd6a9205b03> in <module>
# ----> 1 money.ix[:,0:2]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
